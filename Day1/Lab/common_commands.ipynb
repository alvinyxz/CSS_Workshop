# %%
import pandas as pd
import numpy as np

# %%
# Create a list
my_list = [1, 2, 3, 4, 5]
print(my_list)
# Out:
# [1, 2, 3, 4, 5]

# %%
# Create a dictionary and convert to a DataFrame
my_data_frame = pd.DataFrame({
    "Name": ["Alice", "Bob"],
    "Age": [25, 30]
})
print(my_data_frame)
# Out:
#     Name  Age
# 0  Alice   25
# 1    Bob   30

# %%
# Check the current working directory
import os
os.getcwd()
# Change working directory (optional)
# os.chdir("/your_path_here/")
os.chdir('/Users/alvinzhou/Library/CloudStorage/GoogleDrive-alvinyxz@umn.edu/My Drive/Teaching/CSS_Workshop/2025/CSS_Workshop/Day1')

# %%
data = pd.read_csv("Day1.csv")
# View data
data
# Out:
#      generated_id  Loyaltyvirtue  Authorityvice  Loyaltyvice  Fairnessvice  \
# 0          416155       0.173622       0.130600     0.090973      0.088386
# 1          416156       0.247059       0.171793     0.160124      0.202002
# 2          416157       0.303850       0.171054     0.146459      0.167483
# 3          416158       0.237708       0.242199     0.169393      0.282164
# 4          416159       0.277462       0.277392     0.185772      0.270158
# ..            ...            ...            ...          ...           ...
# 145        416316       0.280763       0.194664     0.145229      0.155025
# 146        416317       0.201211       0.235669     0.133921      0.281397
# 147        416318       0.281751       0.171932     0.194407      0.236546
# 148        416319       0.329628       0.270282     0.262104      0.278945
# 149        416320       0.247963       0.168959     0.158381      0.203012
#
#      Carevirtue  Authorityvirtue  Purityvice  Purityvirtue  Carevice  ...  \
# 0      0.171647         0.222808   -0.014407      0.133585  0.121534  ...
# 1      0.247530         0.212504    0.105922      0.129112  0.265288  ...
# 2      0.249185         0.298192    0.084580      0.171978  0.174610  ...
# 3      0.266385         0.349296    0.180582      0.259245  0.298897  ...
# 4      0.236285         0.337997    0.099364      0.203412  0.287425  ...
# ..          ...              ...         ...           ...       ...  ...
# 145    0.318803         0.298191    0.173921      0.356626  0.201545  ...
# 146    0.233010         0.202564    0.159950      0.168273  0.389338  ...
# 147    0.278444         0.283415    0.104889      0.277340  0.249283  ...
# 148    0.331189         0.321111    0.203763      0.283696  0.268687  ...
# 149    0.242109         0.273949    0.056174      0.148733  0.256530  ...
#
#      geo_mean_probability number_of_votes number_of_errors  C114  C115  \
# 0                 0.79253             367               42  True  True
# 1                 0.80709             170               23  True  True
# 2                 0.94560             361                9  True  True
# 3                 0.95958             166                2  True  True
# 4                 0.95958             166                2  True  True
# ..                    ...             ...              ...   ...   ...
# 145               0.87663             350               18  True  True
# 146               0.99098             168                0  True  True
# 147               0.89955             366               11  True  True
# 148               0.92628             365               13  True  True
# 149               0.92398             368               11  True  True
#
#      affiliation       Party  partyd  retweets_T favorites_T
# 0              D  Democratic       1    1.098612    1.945910
# 1              D  Democratic       1    1.791759    2.397895
# 2              D  Democratic       1    0.693147    1.386294
# 3              R  Republican       0    5.192957    5.771441
# 4              R  Republican       0    5.411646    6.052089
# ..           ...         ...     ...         ...         ...
# 145            D  Democratic       1    2.397895    3.496508
# 146            R  Republican       0    2.302585    2.302585
# 147            R  Republican       0    0.000000    0.000000
# 148            R  Republican       0    2.302585    2.833213
# 149            D  Democratic       1    0.000000    1.609438
#
# [150 rows x 36 columns]

# %%
data.head()
# Out:
#    generated_id  Loyaltyvirtue  Authorityvice  Loyaltyvice  Fairnessvice  \
# 0        416155       0.173622       0.130600     0.090973      0.088386
# 1        416156       0.247059       0.171793     0.160124      0.202002
# 2        416157       0.303850       0.171054     0.146459      0.167483
# 3        416158       0.237708       0.242199     0.169393      0.282164
# 4        416159       0.277462       0.277392     0.185772      0.270158
#
#    Carevirtue  Authorityvirtue  Purityvice  Purityvirtue  Carevice  ...  \
# 0    0.171647         0.222808   -0.014407      0.133585  0.121534  ...
# 1    0.247530         0.212504    0.105922      0.129112  0.265288  ...
# 2    0.249185         0.298192    0.084580      0.171978  0.174610  ...
# 3    0.266385         0.349296    0.180582      0.259245  0.298897  ...
# 4    0.236285         0.337997    0.099364      0.203412  0.287425  ...
#
#    geo_mean_probability number_of_votes number_of_errors  C114  C115  \
# 0               0.79253             367               42  True  True
# 1               0.80709             170               23  True  True
# 2               0.94560             361                9  True  True
# 3               0.95958             166                2  True  True
# 4               0.95958             166                2  True  True
#
#    affiliation       Party  partyd  retweets_T favorites_T
# 0            D  Democratic       1    1.098612    1.945910
# 1            D  Democratic       1    1.791759    2.397895
# 2            D  Democratic       1    0.693147    1.386294
# 3            R  Republican       0    5.192957    5.771441
# 4            R  Republican       0    5.411646    6.052089
#
# [5 rows x 36 columns]

# %%
data.tail()
# Out:
#      generated_id  Loyaltyvirtue  Authorityvice  Loyaltyvice  Fairnessvice  \
# 145        416316       0.280763       0.194664     0.145229      0.155025
# 146        416317       0.201211       0.235669     0.133921      0.281397
# 147        416318       0.281751       0.171932     0.194407      0.236546
# 148        416319       0.329628       0.270282     0.262104      0.278945
# 149        416320       0.247963       0.168959     0.158381      0.203012
#
#      Carevirtue  Authorityvirtue  Purityvice  Purityvirtue  Carevice  ...  \
# 145    0.318803         0.298191    0.173921      0.356626  0.201545  ...
# 146    0.233010         0.202564    0.159950      0.168273  0.389338  ...
# 147    0.278444         0.283415    0.104889      0.277340  0.249283  ...
# 148    0.331189         0.321111    0.203763      0.283696  0.268687  ...
# 149    0.242109         0.273949    0.056174      0.148733  0.256530  ...
#
#      geo_mean_probability number_of_votes number_of_errors  C114  C115  \
# 145               0.87663             350               18  True  True
# 146               0.99098             168                0  True  True
# 147               0.89955             366               11  True  True
# 148               0.92628             365               13  True  True
# 149               0.92398             368               11  True  True
#
#      affiliation       Party  partyd  retweets_T favorites_T
# 145            D  Democratic       1    2.397895    3.496508
# 146            R  Republican       0    2.302585    2.302585
# 147            R  Republican       0    0.000000    0.000000
# 148            R  Republican       0    2.302585    2.833213
# 149            D  Democratic       1    0.000000    1.609438
#
# [5 rows x 36 columns]

# %%
data.columns
# Out:
# Index(['generated_id', 'Loyaltyvirtue', 'Authorityvice', 'Loyaltyvice',
#        'Fairnessvice', 'Carevirtue', 'Authorityvirtue', 'Purityvice',
#        'Purityvirtue', 'Carevice', 'Fairnessvirtue', 'author', 'date.enter',
#        'date.exit', 'followers', 'guid', 'date', 'retweets', 'favorites',
#        'bioname', 'chamber', 'district_code', 'state_abbrev', 'dim1', 'dim2',
#        'log_likelihood', 'geo_mean_probability', 'number_of_votes',
#        'number_of_errors', 'C114', 'C115', 'affiliation', 'Party', 'partyd',
#        'retweets_T', 'favorites_T'],
#       dtype='object')

# %%
data.describe()
# Out:
#         generated_id  Loyaltyvirtue  Authorityvice  Loyaltyvice  Fairnessvice  \
# count     150.000000     150.000000     150.000000   150.000000    150.000000
# mean   416236.513333       0.242918       0.194554     0.152878      0.190153
# std        48.447264       0.069740       0.061534     0.066234      0.065860
# min    416155.000000       0.058709       0.062361     0.019694      0.035054
# 25%    416195.250000       0.200576       0.157150     0.108363      0.149393
# 50%    416234.500000       0.244934       0.181281     0.150479      0.187816
# 75%    416279.750000       0.289619       0.228117     0.188428      0.233337
# max    416320.000000       0.408326       0.497560     0.435622      0.365090
#
#        Carevirtue  Authorityvirtue  Purityvice  Purityvirtue    Carevice  ...  \
# count  150.000000       150.000000  150.000000    150.000000  150.000000  ...
# mean     0.241486         0.272693    0.088504      0.206006    0.227097  ...
# std      0.079960         0.062249    0.071503      0.068837    0.069844  ...
# min      0.076288         0.115949   -0.060824      0.062482    0.065340  ...
# 25%      0.190402         0.239718    0.044245      0.164629    0.179240  ...
# 50%      0.241191         0.274339    0.089374      0.208151    0.231342  ...
# 75%      0.291326         0.316022    0.122717      0.256015    0.268204  ...
# max      0.492762         0.428014    0.350584      0.365910    0.411551  ...
#
#        district_code        dim1        dim2  log_likelihood  \
# count     150.000000  150.000000  150.000000      150.000000
# mean        9.980000    0.127733   -0.033267      -25.538928
# std        12.348665    0.441335    0.275192       14.445410
# min         0.000000   -0.583000   -0.717000      -85.336570
# 25%         1.000000   -0.323750   -0.230500      -33.098228
# 50%         6.000000    0.278000   -0.030000      -23.897500
# 75%        12.000000    0.551500    0.183250      -15.217475
# max        48.000000    0.879000    0.669000       -1.128730
#
#        geo_mean_probability  number_of_votes  number_of_errors      partyd  \
# count            150.000000       150.000000        150.000000  150.000000
# mean               0.922753       317.640000         10.766667    0.433333
# std                0.043019        79.505796          7.525720    0.497196
# min                0.759410       111.000000          0.000000    0.000000
# 25%                0.903900       340.000000          4.000000    0.000000
# 50%                0.930250       359.000000         10.000000    0.000000
# 75%                0.954462       365.000000         16.000000    1.000000
# max                0.990980       368.000000         42.000000    1.000000
#
#        retweets_T  favorites_T
# count  150.000000   150.000000
# mean     1.316857     1.899758
# std      0.941724     1.136111
# min      0.000000     0.000000
# 25%      0.693147     1.386294
# 50%      1.098612     1.945910
# 75%      1.791759     2.397895
# max      5.411646     6.052089
#
# [8 rows x 25 columns]

# %%
data.iloc[:, 0]
# Out:
# 0      416155
# 1      416156
# 2      416157
# 3      416158
# 4      416159
#         ...
# 145    416316
# 146    416317
# 147    416318
# 148    416319
# 149    416320
# Name: generated_id, Length: 150, dtype: int64

# %%
data.iloc[0]
# Out:
# generated_id                         416155
# Loyaltyvirtue                      0.173622
# Authorityvice                        0.1306
# Loyaltyvice                        0.090973
# Fairnessvice                       0.088386
# Carevirtue                         0.171647
# Authorityvirtue                    0.222808
# Purityvice                        -0.014407
# Purityvirtue                       0.133585
# Carevice                           0.121534
# Fairnessvirtue                     0.064194
# author                           repcuellar
# date.enter                       2005-01-03
# date.exit                               NaN
# followers                           20722.0
# guid                     682712911140110336
# date                    2016-01-01 00:00:16
# retweets                                  2
# favorites                                 6
# bioname                      CUELLAR, Henry
# chamber                               House
# district_code                            28
# state_abbrev                             TX
# dim1                                 -0.226
# dim2                                  0.626
# log_likelihood                    -85.33657
# geo_mean_probability                0.79253
# number_of_votes                         367
# number_of_errors                         42
# C114                                   True
# C115                                   True
# affiliation                               D
# Party                            Democratic
# partyd                                    1
# retweets_T                         1.098612
# favorites_T                         1.94591
# Name: 0, dtype: object

# %%
data.iloc[:, -1]
# Out:
# 0      1.945910
# 1      2.397895
# 2      1.386294
# 3      5.771441
# 4      6.052089
#          ...
# 145    3.496508
# 146    2.302585
# 147    0.000000
# 148    2.833213
# 149    1.609438
# Name: favorites_T, Length: 150, dtype: float64

# %%
data.iloc[:10]
# Out:
#    generated_id  Loyaltyvirtue  Authorityvice  Loyaltyvice  Fairnessvice  \
# 0        416155       0.173622       0.130600     0.090973      0.088386
# 1        416156       0.247059       0.171793     0.160124      0.202002
# 2        416157       0.303850       0.171054     0.146459      0.167483
# 3        416158       0.237708       0.242199     0.169393      0.282164
# 4        416159       0.277462       0.277392     0.185772      0.270158
# 5        416160       0.342226       0.173378     0.209511      0.233362
# 6        416161       0.224625       0.153122     0.095095      0.179803
# 7        416163       0.159030       0.216162     0.169300      0.149163
# 8        416164       0.269987       0.201787     0.209444      0.259952
# 9        416165       0.245107       0.160353     0.137105      0.187784
#
#    Carevirtue  Authorityvirtue  Purityvice  Purityvirtue  Carevice  ...  \
# 0    0.171647         0.222808   -0.014407      0.133585  0.121534  ...
# 1    0.247530         0.212504    0.105922      0.129112  0.265288  ...
# 2    0.249185         0.298192    0.084580      0.171978  0.174610  ...
# 3    0.266385         0.349296    0.180582      0.259245  0.298897  ...
# 4    0.236285         0.337997    0.099364      0.203412  0.287425  ...
# 5    0.328720         0.288332    0.073783      0.256300  0.248411  ...
# 6    0.271140         0.277372    0.039230      0.225845  0.244908  ...
# 7    0.164302         0.263907    0.028201      0.115918  0.167876  ...
# 8    0.223340         0.260171    0.043094      0.203088  0.246739  ...
# 9    0.235638         0.290344    0.070080      0.252633  0.249559  ...
#
#    geo_mean_probability number_of_votes number_of_errors   C114  C115  \
# 0               0.79253             367               42   True  True
# 1               0.80709             170               23   True  True
# 2               0.94560             361                9   True  True
# 3               0.95958             166                2   True  True
# 4               0.95958             166                2   True  True
# 5               0.92994             356               10   True  True
# 6               0.97836             169                1   True  True
# 7               0.95823             356                4   True  True
# 8               0.98988             111                0  False  True
# 9               0.82977             356               26   True  True
#
#    affiliation       Party  partyd  retweets_T favorites_T
# 0            D  Democratic       1    1.098612    1.945910
# 1            D  Democratic       1    1.791759    2.397895
# 2            D  Democratic       1    0.693147    1.386294
# 3            R  Republican       0    5.192957    5.771441
# 4            R  Republican       0    5.411646    6.052089
# 5            R  Republican       0    0.693147    1.609438
# 6            R  Republican       0    0.693147    2.197225
# 7            R  Republican       0    1.609438    2.639057
# 8            R  Republican       0    0.000000    1.098612
# 9            R  Republican       0    0.693147    1.945910
#
# [10 rows x 36 columns]

# %%
data['favorites'].describe()
# Out:
# count    150.000000
# mean      15.646667
# std       47.252873
# min        0.000000
# 25%        3.000000
# 50%        6.000000
# 75%       10.000000
# max      424.000000
# Name: favorites, dtype: float64

# %%
data["favorites"].mean()
data["favorites"].median()
data["favorites"].std()
data["favorites"].var()
data["favorites"].max()
data["favorites"].min()
# Out:
# 0

# %%
data[['favorites', 'retweets']].corr()
# The two brackets "[[" indicate which columns to draw
# Out:
#            favorites  retweets
# favorites   1.000000  0.961515
# retweets    0.961515  1.000000

# %%
# you pick out favorites first, and then calculate the correlation with retweets
data["favorites"].corr(data["retweets"])
# Out:
# 0.9615151140008339

# %%
# Plotting
import matplotlib.pyplot as plt

plt.scatter(data["favorites"], data["retweets"])
plt.xlabel("Favorites")
plt.ylabel("Retweets")
plt.title("Scatterplot of Favorites vs Retweets")
plt.show()

# %%
import statsmodels.api as sm
X = data["favorites"]
y = data["retweets"]
X = sm.add_constant(X)
# statsmodels.OLS() does not automatically add a constant term
model = sm.OLS(y, X).fit()
print(model.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:               retweets   R-squared:                       0.925
# Model:                            OLS   Adj. R-squared:                  0.924
# Method:                 Least Squares   F-statistic:                     1813.
# Date:                Tue, 20 May 2025   Prob (F-statistic):           6.25e-85
# Time:                        19:58:08   Log-Likelihood:                -496.96
# No. Observations:                 150   AIC:                             997.9
# Df Residuals:                     148   BIC:                             1004.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.6681      0.576     -1.161      0.248      -1.806       0.470
# favorites      0.4939      0.012     42.574      0.000       0.471       0.517
# ==============================================================================
# Omnibus:                      122.211   Durbin-Watson:                   1.963
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             2711.078
# Skew:                          -2.559   Prob(JB):                         0.00
# Kurtosis:                      23.188   Cond. No.                         52.3
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
